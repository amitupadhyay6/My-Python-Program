# %%
import pandas as pd
from sklearn import datasets

# %%
readfile = pd.read_excel(r"C:\Users\175045\Amit Python\File handling with Pandas\Steps.xlsx")
iris = datasets.load_iris()

# %%
readfile.head()
# Out:
#    Steps                                               Task  \
# 0    1.0  Prepare NDD and submit it for TPR review and r...
# 1    NaN                                                NaN
# 2    2.0  Submit the NDD after TPR approval in NSDP portal.
# 3    NaN                                                NaN
# 4    3.0    raise request for DNS and add device in Netinfo
#
#                                         Comments
# 0                                            NaN
# 1                                            NaN
# 2  Change can be raise in prior to NSDR approval
# 3                                            NaN
# 4                                            NaN

# %%
readfile.columns
# Out:
# Index(['Steps', 'Task', 'Comments'], dtype='object')

# %%
RemovedNA = readfile.dropna()
# Out:
#    Steps                                               Task  \
# 2    2.0  Submit the NDD after TPR approval in NSDP portal.
# 6    4.0                    Lock Down the chanage by Friday
#
#                                             Comments
# 2      Change can be raise in prior to NSDR approval
# 6  If we are planning for the change to go on nex...

# %%
readfile.index
# Out:
# RangeIndex(start=0, stop=25, step=1)

# %%
readfile.iloc[1:10, 2:]
# Out:
#                                             Comments
# 1                                                NaN
# 2      Change can be raise in prior to NSDR approval
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  If we are planning for the change to go on nex...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %%
readfile.values
# Out:
# array([[1.0,
#         'Prepare NDD and submit it for TPR review and review held from by Monday',
#         nan],
#        [nan, nan, nan],
#        [2.0, 'Submit the NDD after TPR approval in NSDP portal.',
#         'Change can be raise in prior to NSDR approval'],
#        [nan, nan, nan],
#        [3.0, 'raise request for DNS and add device in Netinfo', nan],
#        [nan, nan, nan],
#        [4.0, 'Lock Down the chanage by Friday',
#         'If we are planning for the change to go on next weekends'],
#        [nan, nan, nan],
#        [5.0, 'Add change in NPMS and get it approved by Friday', nan],
#        [nan, nan, nan],
#        [6.0,
#         'Send the cabling sheet to DCSD and ask for console and temporary access',
#         nan],
#        [nan, nan, nan],
#        [7.0,
#         "Get the change approved in the calls\nNAM-Tuesday Call only, 9:30PM\nAPAC-  James's call Monday @1:00PM, Wednesday@7:30AM & 12:30PM",
#         nan],
#        [nan, nan, nan],
#        [8.0,
# ...

# %%
readfile.transpose()
# Out:
#                                                          0    1   \
# Steps                                                     1  NaN
# Task      Prepare NDD and submit it for TPR review and r...  NaN
# Comments                                                NaN  NaN
#
#                                                          2    3   \
# Steps                                                     2  NaN
# Task      Submit the NDD after TPR approval in NSDP portal.  NaN
# Comments      Change can be raise in prior to NSDR approval  NaN
#
#                                                        4    5   \
# Steps                                                   3  NaN
# Task      raise request for DNS and add device in Netinfo  NaN
# Comments                                              NaN  NaN
#
#                                                          6    7   \
# Steps                                                     4  NaN
# ...

# %%
readtemp = pd.read_excel(r"C:\Users\175045\Desktop\Extra.xlsx")

# %%
readtemp
# Out:
#     Night Shift  1st  2nd   3rd  4th  5th  Unnamed: 6
# 0           Jan   26   NaN  NaN  NaN  NaN         NaN
# 1           Feb    2     9  NaN  NaN  NaN         NaN
# 2         March  NaN   NaN  NaN  NaN  NaN         NaN
# 3         April    7    14  NaN  NaN  NaN         NaN
# 4           May   26   NaN  NaN  NaN  NaN         NaN
# 5          June    8    22   29  NaN  NaN         NaN
# 6          July    6    13   14   20  NaN         NaN
# 7        August    3     4   10   17   18         NaN
# 8     September   21    28   29  NaN  NaN         NaN
# 9           Oct   19    22   26  NaN  NaN         NaN
# 10          Nov    3     9   10   16  NaN         NaN
# 11         2020  NaN   NaN  NaN  NaN  NaN         NaN
# 12  Night Shift  1st  2nd   3rd  4th  5th         NaN
# 13          Jan   11    25  NaN  NaN  NaN         NaN
# 14          Feb    1    16  NaN  NaN  NaN         NaN
# 15        March    7     8   14   15   21        29.0
# ...

# %%
readtemp.dropna()
# Out:
#    Night Shift 1st 2nd  3rd 4th 5th  Unnamed: 6
# 15       March   7    8  14  15  21        29.0

# %%
readtemp.keys()
# Out:
# Index(['Night Shift', '1st', '2nd ', '3rd', '4th', '5th', 'Unnamed: 6'], dtype='object')

# %%
sheet_read = pd.read_excel(r"C:\Users\175045\Desktop\Extra.xlsx", sheet_name="Comp Off")

# %%
sheet_read
# Out:
#          CHG NUM            WS#                                    Title  \
# 0  CHG0003540570   WS57696394.3                           Taiwan Upgrade
# 1  CHG0003735502  WS65334120.22             Greece SRX to CP replacement
# 2  CHG0003802076     WS65717024  Korea CGMK firewall connectivity change
# 3  CHG0003827606     WS65717024       Korea CGMK CEP Firewall deployment
# 4  CHG0003637891  WS65759394.19                       Korea JA86 Upgrade
#
#       Start date (GMT)             End date Leave date
# 0     17/08/2019 16:00     19/08/2019 02:00    9th Dec
# 1  2019-03-11 05:00:00  2019-03-11 15:00:00   10th Dec
# 2  2019-09-11 05:00:00     16/11/2019 17:00   11th Dec
# 3      16/11/2019 4:30     16/11/2019 14:00   12th Dec
# 4     16/11/2019 15:00     16/11/2019 19:00        NaN
