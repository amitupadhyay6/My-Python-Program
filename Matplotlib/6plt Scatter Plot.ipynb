# %%
from matplotlib import pyplot as plt

# %%
# To compare variable to look for co-relation

# %%
x = [1,2,3,4,5,6,7,8]
y = [5,2,4,2,1,4,5,2]
plt.scatter(x,y, label= "skitcat", color="y")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Scatter Graph")
plt.legend()
plt.show()
