# %%
from matplotlib import pyplot as plt

# %%
# Similar to the line graph to track the progress, best used when you are tracking multiple group over some x axis

# %%
days = [1,2,3,4,5]

# %%
sleep = [7,8,6,11,7]
eat = [2,3,4,3,2]
work = [7,8,7,2,2]
play = [8,5,7,8,13]

plt.title("Stack or Area Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.stackplot(days, sleep, eat, work, play,ex)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot([],[], label="Sleep", linewidth = 5)
plt.plot([],[], label="Eat", linewidth = 5)
plt.plot([],[], label="Work", linewidth = 5)
plt.plot([],[], label="Play", linewidth = 5)
# the above code has been used to show the labels, hence [],[] has been used for this
plt.legend()
plt.show()

# %%
plt.stackplot(days, sleep, eat, work, play, colors = ["m","c","r","k"])
plt.plot([],[], label="Sleep", color="m", linewidth = 5)
plt.plot([],[], label="Eat", color="c",  linewidth = 5)
plt.plot([],[], label="Work", color="r",  linewidth = 5)
plt.plot([],[], label="Play", color="k", linewidth = 5)
plt.legend()
plt.show()
