# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
myseries = pd.Series(np.random.randn(500), index = pd.date_range("18/05/2020", periods=500))

# %%
ts = myseries.cumsum() # to convert the series into cumsum

# %%
ts.plot() # plot the diagram of the ts

# %%
myseries
# Out:
# 2020-05-18    0.124667
# 2020-05-19    0.816801
# 2020-05-20    0.132453
# 2020-05-21    1.887783
# 2020-05-22    0.594808
#                 ...
# 2021-09-25   -0.479135
# 2021-09-26   -0.544883
# 2021-09-27   -0.739599
# 2021-09-28    0.449297
# 2021-09-29   -0.633025
# Freq: D, Length: 500, dtype: float64
